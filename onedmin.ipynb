# %%
from learn_vrc_tst import View, geom, coord
from automol import smiles
import numpy as np
from scipy.spatial.transform import Rotation

# s-vector
s_start = np.asarray([-2, 0, 0])
s_end = np.asarray([2, 0, 0])

# create fragments and pivot points
frag1 = smiles.geometry("CC")
cm1 = geom.center_of_mass(frag1)
geom.translate(frag1, -cm1, in_place=True)

frag2 = smiles.geometry("N#N")
cm2 = geom.center_of_mass(frag2)
geom.translate(frag2, -cm2, in_place=True)

# orient fragment 1 and its pivot vector
R1 = Rotation.from_euler("z", [60], degrees=True)
geom.rotate(frag1, R1, in_place=True)

# orient fragment 2 and its pivot vector
R2 = Rotation.from_euler("z", [-60], degrees=True)
geom.rotate(frag2, R2, in_place=True)

# place fragment 1 pivot point at s-vector start
geom.translate(frag1, s_start, in_place=True)

# place fragment 2 pivot point at s-vector end
geom.translate(frag2, s_end, in_place=True)

view = View()
view.add_arrow(s_end, s_start, color="blue")
view.add_geometry(frag1)
view.add_geometry(frag2)
view.show()
# Out:
# <div id="3dmolviewer_17713429104554915"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17713429104554915" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17713429104554915 = null;
# var warn = document.getElementById("3dmolwarning_17713429104554915");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17713429104554915 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17713429104554915"),{backgroundColor:"white"});
# viewer_17713429104554915.zoomTo();
# 	viewer_17713429104554915.addArrow({"start": {"x": -2, "y": 0, "z": 0}, "end": {"x": 2, "y": 0, "z": 0}, "color": "blue"});
# 	viewer_17713429104554915.addModel("8\n\nC  -1.663387   0.679997  -0.015142\nC  -2.328939  -0.682488   0.027755\nH  -2.501432   1.395169  -0.187688\nH  -0.980148   0.691273  -0.893903\nH  -1.091364   0.899143   0.899204\nH  -3.196082  -0.697820  -0.662710\nH  -2.721287  -0.849974   1.032313\nH  -1.601062  -1.408142  -0.337395","xyz");
# 	viewer_17713429104554915.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17713429104554915.addModel("2\n\nN   2.282373  -0.489085   0.000000\nN   1.717627   0.489085   0.000000","xyz");
# 	viewer_17713429104554915.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# viewer_17713429104554915.render();
# });
# </script>

# %%
geo = geom.concat([frag1, frag2])
print(geom.xyz_string(geo))
# Out:
# 10
#
# C  -1.663387   0.679997  -0.015142
# C  -2.328939  -0.682488   0.027755
# H  -2.501432   1.395169  -0.187688
# H  -0.980148   0.691273  -0.893903
# H  -1.091364   0.899143   0.899204
# H  -3.196082  -0.697820  -0.662710
# H  -2.721287  -0.849974   1.032313
# H  -1.601062  -1.408142  -0.337395
# N   2.282373  -0.489085   0.000000
# N   1.717627   0.489085   0.000000
