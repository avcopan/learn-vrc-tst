# %%
from learn_vrc_tst import View, geom, coord
from automol import smiles
import numpy as np
from scipy.spatial.transform import Rotation

geo = geom.read_xyz_file("c1.xyz")
cm = geom.center_of_mass(geo)
geom.translate(geo, -cm, in_place=True)
rot = geom.rotation_to_inertial_frame(geo)
geom.rotate(geo, rot, in_place=True)

view = View()
view.add_geometry(geo, label=True)
view.add_arrow([1, 0, 0], color="red")
view.add_arrow([0, 1, 0], color="green")
view.add_arrow([0, 0, 1], color="blue")
view.show()
# Out:
# <div id="3dmolviewer_1773629381710399"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1773629381710399" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1773629381710399 = null;
# var warn = document.getElementById("3dmolwarning_1773629381710399");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1773629381710399 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1773629381710399"),{backgroundColor:"white"});
# viewer_1773629381710399.zoomTo();
# 	viewer_1773629381710399.addModel("15\n\nC  -0.799814   1.227428   0.292660\nC  -0.687411  -0.009665   1.211904\nC  -0.795377  -1.233238   0.274206\nC  -0.418822  -0.661092  -1.071170\nC  -0.421150   0.676920  -1.061124\nH  -1.822098   1.620669   0.261823\nH  -0.153462   2.046623   0.614583\nH  -1.437733  -0.016937   2.002451\nH   0.293722  -0.011584   1.692380\nH  -0.145870  -2.054679   0.583797\nH  -1.816199  -1.629753   0.237539\nH  -0.226103  -1.273286  -1.944150\nH  -0.230587   1.302825  -1.924777\nO   2.578781   0.000482   0.193305\nH   1.791152   0.004282  -0.382198","xyz");
# 	viewer_1773629381710399.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1773629381710399.addLabel(0,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 0});
# 	viewer_1773629381710399.addLabel(1,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 1});
# 	viewer_1773629381710399.addLabel(2,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 2});
# 	viewer_1773629381710399.addLabel(3,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 3});
# 	viewer_1773629381710399.addLabel(4,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 4});
# 	viewer_1773629381710399.addLabel(5,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 5});
# 	viewer_1773629381710399.addLabel(6,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 6});
# 	viewer_1773629381710399.addLabel(7,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 7});
# 	viewer_1773629381710399.addLabel(8,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 8});
# 	viewer_1773629381710399.addLabel(9,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 9});
# 	viewer_1773629381710399.addLabel(10,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 10});
# 	viewer_1773629381710399.addLabel(11,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 11});
# 	viewer_1773629381710399.addLabel(12,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 12});
# 	viewer_1773629381710399.addLabel(13,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 13});
# 	viewer_1773629381710399.addLabel(14,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 14});
# 	viewer_1773629381710399.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 1, "y": 0, "z": 0}, "color": "red"});
# 	viewer_1773629381710399.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0, "y": 1, "z": 0}, "color": "green"});
# 	viewer_1773629381710399.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0, "y": 0, "z": 1}, "color": "blue"});
# viewer_1773629381710399.render();
# });
# </script>
