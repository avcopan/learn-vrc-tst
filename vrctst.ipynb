# %% [markdown]
# ## VRC-TST
#
# Following along with the implementation detailed in the SI of [this paper](https://doi.org/10.1073/pnas.1616208113)...

# %% [markdown]
# **Step 1.** Set the length of the reaction coordinate `s` to `s_min`.

# %%
from automol import smiles
from learn_vrc_tst import geom, view
from importlib import reload

reload(geom)
reload(view)

s = s_min = 5  # Set to 10 A initially

frag1 = smiles.geometry("[CH3]")
frag2 = smiles.geometry("[CH3]")

geom.translate(frag2, [s, 0, 0], in_place=True)

vie = view.empty()
vie = view.geometry(frag1, vie)
vie = view.geometry(frag2, vie)
vie.show()
# Out:
# <div id="3dmolviewer_17701564334906995"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17701564334906995" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17701564334906995 = null;
# var warn = document.getElementById("3dmolwarning_17701564334906995");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17701564334906995 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17701564334906995"),{backgroundColor:"white"});
# viewer_17701564334906995.zoomTo();
# 	viewer_17701564334906995.addModel("4\n\nC   0.010979  -0.007273   0.277261\nH   1.026126  -0.237963  -0.095317\nH  -0.734105  -0.751586  -0.091922\nH  -0.303000   0.996822  -0.090022","xyz");
# 	viewer_17701564334906995.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17701564334906995.zoomTo();
# 	viewer_17701564334906995.addModel("4\n\nC   5.006932   0.012965   0.290451\nH   6.046733  -0.127770  -0.098215\nH   4.389324  -0.830416  -0.093161\nH   4.557010   0.945221  -0.099075","xyz");
# 	viewer_17701564334906995.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17701564334906995.zoomTo();
# viewer_17701564334906995.render();
# });
# </script>
